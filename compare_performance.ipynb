# %%
import matplotlib.image as mpimg
from matplotlib import rcParams
import matplotlib.pyplot as plt

# %%
model_id = '1638198758'

los_img = mpimg.imread(f'./outputs/{model_id}/loss.png')
acc_img = mpimg.imread(f'./outputs/{model_id}/accuracy.png')

rcParams['figure.figsize'] = 18, 15

_, ax = plt.subplots(1, 2)

ax[0].imshow(los_img)
ax[0].axis('off')

ax[1].imshow(acc_img)
ax[1].axis('off')
# Out:
# (-0.5, 431.5, 287.5, -0.5)

# %%
model_id = '1638199685'

los_img = mpimg.imread(f'./outputs/{model_id}/loss.png')
acc_img = mpimg.imread(f'./outputs/{model_id}/accuracy.png')

rcParams['figure.figsize'] = 18, 15

_, ax = plt.subplots(1, 2)

ax[0].imshow(los_img)
ax[0].axis('off')

ax[1].imshow(acc_img)
ax[1].axis('off')
# Out:
# (-0.5, 431.5, 287.5, -0.5)

# %%
model_id = '1638203413'

los_img = mpimg.imread(f'./outputs/{model_id}/loss.png')
acc_img = mpimg.imread(f'./outputs/{model_id}/accuracy.png')

rcParams['figure.figsize'] = 18, 15

_, ax = plt.subplots(1, 2)

ax[0].imshow(los_img)
ax[0].axis('off')

ax[1].imshow(acc_img)
ax[1].axis('off')
# Out:
# (-0.5, 431.5, 287.5, -0.5)

# %%
model_id = '1638217828'

los_img = mpimg.imread(f'./outputs/{model_id}/loss.png')
acc_img = mpimg.imread(f'./outputs/{model_id}/accuracy.png')

rcParams['figure.figsize'] = 18, 15

_, ax = plt.subplots(1, 2)

ax[0].imshow(los_img)
ax[0].axis('off')

ax[1].imshow(acc_img)
ax[1].axis('off')
# Out:
# (-0.5, 431.5, 287.5, -0.5)

# %%
model_id = '1638225518'

los_img = mpimg.imread(f'./outputs/{model_id}/loss.png')
acc_img = mpimg.imread(f'./outputs/{model_id}/accuracy.png')

rcParams['figure.figsize'] = 18, 15

_, ax = plt.subplots(1, 2)

ax[0].imshow(los_img)
ax[0].axis('off')

ax[1].imshow(acc_img)
ax[1].axis('off')
# Out:
# (-0.5, 431.5, 287.5, -0.5)

# %%
model_id = '1638232901'

los_img = mpimg.imread(f'./outputs/{model_id}/loss.png')
acc_img = mpimg.imread(f'./outputs/{model_id}/accuracy.png')

rcParams['figure.figsize'] = 18, 15

_, ax = plt.subplots(1, 2)

ax[0].imshow(los_img)
ax[0].axis('off')

ax[1].imshow(acc_img)
ax[1].axis('off')
# Out:
# (-0.5, 431.5, 287.5, -0.5)

# %%
model_id = '1638234092'

los_img = mpimg.imread(f'./outputs/{model_id}/loss.png')
acc_img = mpimg.imread(f'./outputs/{model_id}/accuracy.png')

rcParams['figure.figsize'] = 18, 15

_, ax = plt.subplots(1, 2)

ax[0].imshow(los_img)
ax[0].axis('off')

ax[1].imshow(acc_img)
ax[1].axis('off')
# Out:
# (-0.5, 431.5, 287.5, -0.5)

# %%
model_id = '1638286895'

los_img = mpimg.imread(f'./outputs/{model_id}/loss.png')
acc_img = mpimg.imread(f'./outputs/{model_id}/accuracy.png')

rcParams['figure.figsize'] = 18, 15

_, ax = plt.subplots(1, 2)

ax[0].imshow(los_img)
ax[0].axis('off')

ax[1].imshow(acc_img)
ax[1].axis('off')
# Out:
# (-0.5, 431.5, 287.5, -0.5)

# %%
model_id = '1638299903'

los_img = mpimg.imread(f'./outputs/{model_id}/loss.png')
acc_img = mpimg.imread(f'./outputs/{model_id}/accuracy.png')

rcParams['figure.figsize'] = 18, 15

_, ax = plt.subplots(1, 2)

ax[0].imshow(los_img)
ax[0].axis('off')

ax[1].imshow(acc_img)
ax[1].axis('off')
# Out:
# (-0.5, 431.5, 287.5, -0.5)
